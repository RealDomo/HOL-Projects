# %% [markdown]
# <a href="https://colab.research.google.com/github/RealDomo/HOL-Projects/blob/main/HOL_AI_Week_2_Project_1_Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ps = {
      'Song': ['Money Trees', 'Love Yours', 'Trust Issues', 'Swimming Pools', 'wacced out murals', 'Ultralight Beam', '30 for 30', 'Stan', 'tv off', 'Headlines', 'No Role Modelz'],
      'Artist': ['Kendrick Lamar', 'J. Cole', 'Drake', 'Kendrick Lamar', 'Kendrick Lamar', 'Kanye West', 'SZA', 'Eminem', 'Kendrick Lamar', 'Drake', 'J. Cole'],
      'Energy': [0.9, 0.4, 0.5, 0.6, 0.9, 0.5, 0.5, 0.6, 1.0, 0.6, 0.8],
      'Day_Played': ['Saturday', 'Friday', 'Saturday', 'Sunday', 'Tuesday', 'Monday', 'Thursday', 'Wednesday', 'Saturday', 'Wednesday', 'Sunday']
      }

playlist = pd.DataFrame(ps)

print(playlist, "\n")

print(playlist.head())
# Out:
#                  Song          Artist  Energy Day_Played
# 0         Money Trees  Kendrick Lamar     0.9   Saturday
# 1          Love Yours         J. Cole     0.4     Friday
# 2        Trust Issues           Drake     0.5   Saturday
# 3      Swimming Pools  Kendrick Lamar     0.6     Sunday
# 4   wacced out murals  Kendrick Lamar     0.9    Tuesday
# 5     Ultralight Beam      Kanye West     0.5     Monday
# 6           30 for 30             SZA     0.5   Thursday
# 7                Stan          Eminem     0.6  Wednesday
# 8              tv off  Kendrick Lamar     1.0   Saturday
# 9           Headlines           Drake     0.6  Wednesday
# 10     No Role Modelz         J. Cole     0.8     Sunday
#
#                 Song          Artist  Energy Day_Played
# 0        Money Trees  Kendrick Lamar     0.9   Saturday
# 1         Love Yours         J. Cole     0.4     Friday
# 2       Trust Issues           Drake     0.5   Saturday
# 3     Swimming Pools  Kendrick Lamar     0.6     Sunday
# ...

# %%
artistCounts = playlist['Artist'].value_counts()

print(artistCounts.index[0])
# Out:
# Kendrick Lamar

# %%
averageEnergy = playlist['Energy'].mean()

if averageEnergy < 0.4:
  print("I'm just a chill guy")
elif averageEnergy > 0.6:
  print("I like high energy music")
else:
  print("I like medium energy music")

print(averageEnergy)
# Out:
# I like high energy music
# 0.6636363636363636

# %%
import matplotlib.pyplot as plt

day_counts = playlist['Day_Played'].value_counts()
plt.bar(day_counts.index, day_counts.values)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.style.use('ggplot')
plt.show()

print("I think I listen to music mostly on Saturday because I don't have school.")
# Out:
# I think I listen to music mostly on Saturday because I don't have school.

# %%
import matplotlib.pyplot as plt

plt.bar(artistCounts.index, artistCounts.values)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.style.use('dark_background')
plt.show()

print("I think this is meaningful because it shows the number of songs by each artist graphically.")
# Out:
# I think this is meaningful because it shows the number of songs by each artist graphically.
